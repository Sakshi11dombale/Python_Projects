# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
hd=pd.read_csv("heart.csv")
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'cp'}>,
#         <Axes: title={'center': 'trestbps'}>],
#        [<Axes: title={'center': 'chol'}>,
#         <Axes: title={'center': 'fbs'}>,
#         <Axes: title={'center': 'restecg'}>,
#         <Axes: title={'center': 'thalach'}>],
#        [<Axes: title={'center': 'exang'}>,
#         <Axes: title={'center': 'oldpeak'}>,
#         <Axes: title={'center': 'slope'}>,
#         <Axes: title={'center': 'ca'}>],
#        [<Axes: title={'center': 'thal'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
hd['target'].plot()
# Out:
# <Axes: >

# %%
hd['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
hd['target'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='target'>

# %%
hd['target'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
hd['target'].value_counts().plot.barh()
# Out:
# <Axes: ylabel='target'>

# %%
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hd['sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
hd['slope'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
x=hd['trestbps'].value_counts()
y=hd['trestbps'].value_counts()
plt.scatter(x,y)
plt.show()

# %%
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hd['oldpeak'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='oldpeak'>

# %% [markdown]
# loc and iloc

# %%
ani=pd.Series(['cat','dog','cow','ox'],index=[1,2,3,4])
print(ani)
# Out:
# 1    cat
# 2    dog
# 3    cow
# 4     ox
# dtype: object

# %%
ani.loc[1]
# Out:
# 'cat'

# %%
ani.iloc[1]
# Out:
# 'dog'

# %%
hd.loc[125]
# Out:
# age          34.0
# sex           0.0
# cp            1.0
# trestbps    118.0
# chol        210.0
# fbs           0.0
# restecg       1.0
# thalach     192.0
# exang         0.0
# oldpeak       0.7
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 125, dtype: float64

# %%
hd.loc[52:76].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
hd.iloc[53:78].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Conditional Filtering
# ==,>,>=,<,<=,!=

# %%
hd[hd['target']==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 162   41    1   1       120   157    0        1      182      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd['target']==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 165   67    1   0       160   286    0        0      108      1      1.5
# 166   67    1   0       120   229    0        0      129      1      2.6
# 167   62    0   0       140   268    0        0      160      0      3.6
# 168   63    1   0       130   254    0        0      147      0      1.4
# 169   53    1   0       140   203    1        0      155      1      3.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 165      1   3     2       0
# 166      1   2     3       0
# ...

# %%
hd[hd['age']>50]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
hd[hd['oldpeak']>2]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 17    66    0   3       150   226    0        1      114      0      2.6
# 42    45    1   0       104   208    0        0      148      1      3.0
# 76    51    1   2       125   245    1        0      166      0      2.4
# 101   59    1   3       178   270    0        0      145      0      4.2
# 150   66    1   0       160   228    0        0      138      0      2.3
# 166   67    1   0       120   229    0        0      129      1      2.6
# 167   62    0   0       140   268    0        0      160      0      3.6
# 169   53    1   0       140   203    1        0      155      1      3.1
# 173   58    1   2       132   224    0        0      173      0      3.2
# 174   60    1   0       130   206    0        0      132      1      2.4
# ...

# %%
hd.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hd[hd['cp']==1]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 12    49    1   1       130   266    0        1      171      0      0.6
# 25    71    0   1       160   302    0        1      162      0      0.4
# 30    41    0   1       105   198    0        1      168      0      0.0
# 32    44    1   1       130   219    0        0      188      0      0.0
# 41    48    1   1       130   245    0        0      180      0      0.2
# 45    52    1   1       120   325    0        1      172      0      0.2
# 55    52    1   1       134   201    0        1      158      0      0.8
# 61    54    1   1       108   309    0        1      156      0      0.0
# ...

# %%
hd[hd['cp']==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 10    54    1   0       140   239    0        1      160      0      1.2
# 18    43    1   0       150   247    0        1      171      0      1.5
# 20    59    1   0       135   234    0        1      161      0      0.5
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
#
#      slope  ca  thal  target
# 4        2   0     2       1
# 5        1   0     1       1
# ...

# %%
hd[hd['chol']>=100]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
hd[hd['chol']<=200]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5     57    1   0       140   192    0        1      148      0      0.4
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 24    40    1   3       140   199    0        1      178      1      1.4
# 27    51    1   2       110   175    0        1      123      0      0.6
# 29    53    1   2       130   197    1        0      152      0      1.2
# 30    41    0   1       105   198    0        1      168      0      0.0
# 31    65    1   0       120   177    0        1      140      0      0.4
# 35    46    0   2       142   177    0        0      160      1      1.4
# 53    44    0   2       108   141    0        1      175      0      0.6
# 58    34    1   3       118   182    0        0      174      0      0.0
# 62    52    1   3       118   186    0        0      190      0      0.0
# ...

# %%
hd[hd['thalach']!=200]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## Adding new col with applying some maths

# %%
hd['pro_data']=hd['trestbps']*hd['chol']
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  pro_data
# 0        0   0     1       1     33785
# ...

# %% [markdown]
# ## Column Drop Method

# %%
hd.drop('pro_data',axis=1 ,inplace=True)
hd
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## Cross Tab

# %%
hd.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
pd.crosstab(hd['sex'],hd['cp'])
# Out:
# cp     0   1   2   3
# sex
# 0     39  18  35   4
# 1    104  32  52  19

# %%
pd.crosstab(hd['sex'],hd['target'])
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %% [markdown]
# ## Special Graphs

# %%
hd.plot(kind='bar')
# Out:
# <Axes: >

# %%
pd.crosstab(hd['sex'],hd['cp']).plot.bar()
# Out:
# <Axes: xlabel='sex'>

# %%
import seaborn as sns
correlation=hd.corr()
plt.figure(figsize=(10,6))
sns.heatmap(correlation,annot=True,cmap='coolwarm',
            fmt='.2f',linewidths=0.5,cbar=True)
plt.show()

# %% [markdown]
# ## Density Plot

# %%
plt.subplot(3,2,1)
x=sns.kdeplot(hd['age'])

plt.subplot(3,2,2)
x=sns.kdeplot(hd['sex'])

plt.subplot(3,2,3)
x=sns.kdeplot(hd['fbs'])

plt.subplot(3,2,4)
x=sns.kdeplot(hd['cp'])

plt.subplot(3,2,5)
x=sns.kdeplot(hd['chol'])

plt.subplot(3,2,6)
x=sns.kdeplot(hd['thal'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=hd['target'],y=hd['cp'],data=hd)
# Out:
# <Axes: xlabel='target', ylabel='cp'>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(hd,alpha=0.2,figsize=(10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='age', ylabel='age'>,
#         <Axes: xlabel='sex', ylabel='age'>,
#         <Axes: xlabel='cp', ylabel='age'>,
#         <Axes: xlabel='trestbps', ylabel='age'>,
#         <Axes: xlabel='chol', ylabel='age'>,
#         <Axes: xlabel='fbs', ylabel='age'>,
#         <Axes: xlabel='restecg', ylabel='age'>,
#         <Axes: xlabel='thalach', ylabel='age'>,
#         <Axes: xlabel='exang', ylabel='age'>,
#         <Axes: xlabel='oldpeak', ylabel='age'>,
#         <Axes: xlabel='slope', ylabel='age'>,
#         <Axes: xlabel='ca', ylabel='age'>,
#         <Axes: xlabel='thal', ylabel='age'>,
#         <Axes: xlabel='target', ylabel='age'>],
#        [<Axes: xlabel='age', ylabel='sex'>,
#         <Axes: xlabel='sex', ylabel='sex'>,
#         <Axes: xlabel='cp', ylabel='sex'>,
#         <Axes: xlabel='trestbps', ylabel='sex'>,
#         <Axes: xlabel='chol', ylabel='sex'>,
#         <Axes: xlabel='fbs', ylabel='sex'>,
#         <Axes: xlabel='restecg', ylabel='sex'>,
# ...
